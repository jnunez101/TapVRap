5'], ['3', '-156.25', '687.5', '718.75'], ['4', '-125', '406.25', '937.5'], ['0', '62.5', '-875', '500'], ['1', '-187.5', '218.75', '937.5'], ['2', '-31.25', '562.5', '812.5'], ['3', '-156.25', '687.5', '718.75'], ['4', '-93.75', '406.25', '937.5'], ['0', '62.5', '-875', '562.5'], ['1', '-218.75', '187.5', '968.75'], ['2', '-31.25', '531.25', '812.5'], ['3', '-156.25', '687.5', '687.5'], ['4', '-93.75', '375', '906.25'], ['0', '62.5', '-843.75', '562.5'], ['1', '-187.5', '156.25', '968.75'], ['2', '-31.25', '531.25', '843.75'], ['3', '-156.25', '656.25', '718.75'], ['4', '-125', '375', '937.5'], ['0', '1365', '1890', '-1365'], ['1', '-26.474', '-904.02', '518.988'], ['0', '62.5', '-843.75', '562.5'], ['1', '-218.75', '187.5', '968.75'], ['2', '-31.25', '562.5', '843.75'], ['3', '-156.25', '687.5', '718.75'], ['4', '-93.75', '406.25', '937.5'], ['0', '-4830', '2380', '-1435'], ['1', '-26.108', '-915.732', '504.592'], ['0', '-3990', '3290', '-910'], ['1', '-39.406', '-914.512', '525.21'], ['0', '-2187.5', '3745', '-997.5'], ['1', '-34.282', '-903.044', '525.332'], ['0', '-2975', '3202.5', '-1557.5'], ['1', '-22.814', '-919.88', '518.622'], ['0', '-2940', '7927.5', '-4637.5'], ['1', '-14.396', '-911.584', '489.464'], ['0', '-4777.5', '9135', '-3482.5'], ['1', '-15.982', ' ...

# %%
from string import ascii_letters, punctuation, whitespace
import re
nono = ['(', ')']
newlist = []
for i in range(len(mylist)):
    if len(mylist[i]) < 3:
        continue
    for y in range(len(mylist[i])):
        mylist[i][y] = re.sub(r'[^\d.]+', '', mylist[i][y])
        mylist[i][y] = "".join(filter(lambda x: x not in nono, mylist[i][y]))
        mylist[i][y] = float(mylist[i][y])
        #print(mylist[i][y])

# %%
for i in range(len(mylist)):
    if type(mylist[i][0]) is str:
        continue
    else:
        newlist.append(mylist[i])

# %%
import matplotlib as plt

def Sort(mylist):
    return(sorted(mylist, key = lambda x: x[0]))

print(Sort(newlist))
# Out:
# [[0.0, 156.25, 875.0, 406.25], [0.0, 62.5, 781.25, 531.25], [0.0, 14227.5, 112525.0, 8487.5], [0.0, 26477.5, 106540.0, 595.0], [0.0, 332.5, 57470.0, 6370.0], [0.0, 9747.5, 25147.5, 14420.0], [0.0, 93.75, 781.25, 625.0], [0.0, 62.5, 843.75, 625.0], [0.0, 93.75, 843.75, 625.0], [0.0, 31.25, 875.0, 562.5], [0.0, 0.0, 906.25, 593.75], [0.0, 62.5, 875.0, 531.25], [0.0, 9695.0, 55702.5, 9677.5], [0.0, 1155.0, 47005.0, 11795.0], [0.0, 6790.0, 39095.0, 10885.0], [0.0, 7420.0, 32427.5, 9747.5], [0.0, 1032.5, 21630.0, 3465.0], [0.0, 3045.0, 6965.0, 665.0], [0.0, 3167.5, 3675.0, 1732.5], [0.0, 1050.0, 7857.5, 1925.0], [0.0, 157.5, 8207.5, 1120.0], [0.0, 7140.0, 770.0, 1452.5], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 875.0, 531.25], [0.0, 62.5, 875.0, 500.0], [0.0, 62.
0, 62.5, 875.0, 531.25], [0.0, 62.5, 875.0, 562.5], [0.0, 62.5, 875.0, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 1750.0, 1785.0, 875.0], [0.0, 1925.0, 2170.0, 752.5], [0.0, 1732.5, 2222.5, 472.5], [0.0, 735.0, 3762.5, 1400.0], [0.0, 1242.5, 5512.5, 2135.0], [0.0, 62.5, 875.0, 562.5], [0.0, 5740.0, 11865.0, 1120.0], [0.0, 62.5, 875.0, 531.25], [0.0, 62.5, 875.0, 593.75], [0.0, 31.25, 843.75, 562.5], [0.0, 1610.0, 4392.5, 105.0], [0.0, 962.5, 4322.5, 455.0], [0.0, 62.5, 875.0, 562.5], [0.0, 62.5, 875.0, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 875.0, 562.5], [0.0, 62.5, 875.0, 562.5], [0.0, 62.5, 875.0, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 2117.5, 1732.5, 455.0], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 843.75, 562.5], [0.0, 62.5, 875.0, 562.5], [0.0, 4007.5, 11392.5, 1995.0], [0.0, 62.5, 843.75, 562.5], [0.0, 700.0, 7210.0, 1645.0], [0.0, 2 ...

# %%
import matplotlib.pyplot as plt
import matplotlib
finger = 0.0
z = []
for i in range(len(newlist)):
    if newlist[i][0] == finger:
        z.append(newlist[i][3])
zVec = np.array(z)
print(zVec)
time = np.arange(0,len(z),1)
fig, ax = plt.subplots()
ax.plot(time,zVec)
ax.set(xlabel='time', ylabel='Z', title='uwu')
ax.grid()
plt.show()
print(max(zVec))
print(min(zVec))
#ax.plot(newlist[y,0], newlist[y,4])
# Out:
# [  406.25   531.25  8487.5  ...   562.5     87.5  10272.5 ]
# 281995.0
# 0.0

# %%
#time = []
x = []
for i in range(len(newlist)):
    if newlist[i][0] == finger:
        #time.append(newlist[i][0])
        x.append(newlist[i][1])
fig, ax = plt.subplots()
ax.plot(time,x)
ax.set(xlabel='time', ylabel='X', title='uwu')
ax.grid()
plt.show()
print(max(x))
print(min(x))
# Out:
# 357315.0
# 0.0

# %%
y = []
for i in range(len(newlist)):
    if newlist[i][0] == finger:
        #time.append(newlist[i][0])
        y.append(newlist[i][2])
fig, ax = plt.subplots()
ax.plot(time,y)
ax.set(xlabel='time', ylabel='Y', title='uwu')
ax.grid()
plt.show()
print(max(y))
print(min(y))
# Out:
# 411337.5
# 0.0

# %%
fig, ax = plt.subplots()
ax.plot(time,y)
ax.plot(time,x)
ax.plot(time,z)
ax.set(xlabel='time', ylabel='Y', title='uwu')
ax.grid()
plt.show()
print(max(y))
print(min(y))
# Out:
# 411337.5
# 0.0

# %%
import numpy as np
xp = np.array(x)
yp = np.array(y)
zp = np.array(z)
combine = xp + yp + zp
fig, ax = plt.subplots()
ax.plot(time,combine)
ax.set(xlabel='time', ylabel='Y', title='uwu')
ax.grid()
plt.show()
print(max(combine))
print(min(combine))
# Out:
# 808517.5
# 280.0
